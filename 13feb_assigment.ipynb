# %%
#Q1. Explain why we have to use the Exception class while creating a Custom Exception.
#ans-
# When you define a custom exception in Python, you should always inherit from the built-in Exception class or one of its subclasses. This is because Exception is the base class for all built-in exceptions in Python, and it provides all the necessary functionality to handle and report exceptions.

#These methods and attributes include:
#1-__init__(self, *args) 
#2-args
#3-__str__(self)
#4-__repr__(self)

# %%
#Q2-Write a python program to print Python Exception Hierarchy.

#ans- 
def print_exception_hierarchy(baseExceptions, indent=0):
    for exec in baseExceptions:
        print(" "*indent, exec.__name__)
        if issubclass(exec, BaseException):
            print_exception_hierarchy(exec.__subclasses__(), indent+2)
        

print_exception_hierarchy(BaseException.__subclasses__())
# Out:
# Exception
# TypeError
# FloatOperation
# MultipartConversionError
# StopAsyncIteration
# StopIteration
# ImportError
# ModuleNotFoundError
# PackageNotFoundError
# ZipImportError
# OSError
# ConnectionError
# BrokenPipeError
# ConnectionAbortedError
# ConnectionRefusedError
# ConnectionResetError
# RemoteDisconnected
# BlockingIOError
# ChildProcessError
# FileExistsError
# FileNotFoundError
# IsADirectoryError
# NotADirectoryError
# InterruptedError
# InterruptedSystemCall
# PermissionError
# ProcessLookupError
# TimeoutError
# UnsupportedOperation
# herror
# gaierror
# SSLError
# SSLCertVerificationError
# SSLZeroReturnError
# SSLWantWriteError
# SSLWantReadError
# SSLSyscallError
# SSLEOFError
# Error
# SameFileError
# SpecialFileError
# ExecError
# ReadError
# URLError
# HTTPError
# ContentTooShortError
# BadGzipFile
# EOFError
# IncompleteReadError
# RuntimeError
# RecursionError
# NotImplementedError
# ZMQVersionError
# StdinNotImplementedError
# _DeadlockError
# ...

# %%
#q3-What errors are defined in the ArithmeticError class? Explain any two with an example.

#ans-
# The ArithmeticError class is a built-in exception class in Python that is raised when there is an error in an arithmetic operation. It is the base class for all arithmetic-related exceptions.
# there are two type of error commonly we saw 

#1.ZeroDivisionError-This error is raised when a division operation is attempted with a divisor of zero.
try:
  arithmetic = 3/0
  print(arithmetic)
except ArithmeticError:
  print("error")  
#2Floating error- a FloatingPointError is a type of arithmetic error that is raised when a floating-point operation fails to produce a finite result, due to overflow or underflow, or when a division by zero occurs.
try:
  a = 1.0e1000
  b = 1.0e-1000
  c = a + b
except FloatingPointError:
  print("im trying to handle folating point error")
# Out:
# error

# %%
#3 Why LookupError class is used? Explain with an example KeyError and IndexError?

#LookupError is the Base class for errors raised when something can’t be found. 
#The base class for the exceptions that are raised when a key or index used on a mapping or sequence is invalid: 
#These are  IndexError, KeyError.
 #indexError
try:
    m=[1,2,2,5,6]
    print(m[5])
except IndexError as e:
    print(e)

    #key error 
    
#A Python KeyError exception is what is raised when you try to access a key that isn’t in a dictionary (dict).
try :
    t = {"key" :"name" , 1 : [2,5,1,5]}
    print(t["key2"])
except KeyError as e : 
    print(e)
# Out:
# list index out of range
# 'key2'

# %%
# Q5. Explain ImportError. What is ModuleNotFoundError?

#Ans-Import error are raised when an import statement has trouble successfully importing the specified module.
 
#ModuleNotFoundError are such a problem is due to an invalid or incorrect path, which will raise a ModuleNotFoundError

# %%
#6 List down some best practices for exception handling in python.

#ans- 1. always use specific exception
try :
    5/0
except ZeroDivisionError as f :
    print(f)
#2.print always proper message 
try :
    6/0
except ZeroDivisionError as e :
    print("i am trying to handle a zerodivision error"  , e)

#3 always try to log your error
import logging
logging.basicConfig(filename = "error.log" , level = logging.ERROR)
try :
    10/0
except ZeroDivisionError as e :
    logging.error("i am trying to handle a zerodivision error {} ".format(e) )
# Out:
# division by zero
# i am trying to handle a zerodivision error division by zero
